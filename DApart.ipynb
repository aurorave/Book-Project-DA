# %% [markdown]
# 코로나 시기별(1~4기) 인터파크 도서 판매 장르

# %%
import pandas as pd
import numpy as np

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\maeve\\AIB 14\\Section6\\Codestates Project 2\\jupyter'

# %%
ip_month_grade = pd.read_csv(r"\..data\clean\interpark\interpark_month_grade.csv")
ip_month_grade.shape
# Out:
# (24682, 5)

# %%
# # Unnamed 컬럼 삭제
# # 1. 첫 번째 컬럼을 index로 사용하도록 지정하여 로드
# input = pd.read_csv('data.csv', index_col = 0)
# # 2. Unnamed: 0 컬럼을 drop하여 제거
# input.drop(['Unnamed: 0'], axis = 1, inplace = True)

ip_month_grade = pd.read_csv(r"C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\interpark_month_grade.csv")
ip_month_info = pd.read_csv(r"C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\interpark_month_info.csv")
ip_month_sales = pd.read_csv(r"C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\interpark_month_sales.csv")

ip_year_grade = pd.read_csv(r"C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\interpark_year_grade.csv")
ip_year_info = pd.read_csv(r"C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\interpark_year_info.csv", index_col = 0)
ip_year_sales = pd.read_csv(r"C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\interpark_year_sales.csv")

ip_month_grade.shape, ip_month_info.shape, ip_month_sales.shape
# Out:
# ((24682, 5), (26445, 10), (26445, 5))

# %%
ip_year_grade.shape, ip_year_info.shape, ip_year_sales.shape
# Out:
# ((1400, 5), (1500, 9), (1500, 5))

# %%
ip_month_grade.drop(['Unnamed: 0', 'index'], axis = 1, inplace = True)
ip_month_grade.head(3)
# Out:
#     ProdNo  review    date
# 0   109266     9.5  200703
# 1   154973     9.4  200703
# 2  1037600     9.7  200703

# %%
ip_month_grade.ProdNo = ip_month_grade.ProdNo.astype('str')
ip_month_grade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24682 entries, 0 to 24681
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ProdNo  24682 non-null  object
#  1   review  24682 non-null  float64
#  2   date    24682 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 578.6+ KB

# %%
ip_month_info.drop(['Unnamed: 0', 'index'], axis = 1, inplace = True)
ip_month_info.head(3)
# Out:
#    accuCnt  aggrCnt                        author      category  \
# 0        0     6661  토드 홉킨스  레이 힐버트신윤경 역           자기계발
# 1        0     4906                  정철진           경제경영
# 2        0     4527   오쿠다 히데오(奧田英朗)이영미 역             소설
#
#             title    ProdNo    date  rank
# 0            청소부밥  15593842  200703     1
# 1  대한민국20대재테크에미쳐라  14623522  200703     2
# 2            공중그네   2580891  200703     3

# %%
ip_month_info.ProdNo = ip_month_info.ProdNo.astype('str')
ip_month_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26445 entries, 0 to 26444
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   accuCnt   26445 non-null  int64
#  1   aggrCnt   26445 non-null  int64
#  2   author    26445 non-null  object
#  3   category  26445 non-null  object
#  4   title     25052 non-null  object
#  5   ProdNo    26445 non-null  object
#  6   date      26445 non-null  int64
#  7   rank      26445 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 1.6+ MB

# %%
ip_month_sales.drop(['Unnamed: 0', 'index'], axis = 1, inplace = True)
ip_month_sales = ip_month_sales.rename(columns={'구매력?': 'sales'})
# df = df.rename(columns={'pub_year': 'pub_date'})
ip_month_sales.head(3)
# Out:
#    sales  ProdNo    date
# 0  21628   75899  200703
# 1  29968  109266  200703
# 2  25645  154973  200703

# %%
ip_month_sales.ProdNo = ip_month_sales.ProdNo.astype('str')
ip_month_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26445 entries, 0 to 26444
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sales   26445 non-null  int64
#  1   ProdNo  26445 non-null  object
#  2   date    26445 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 619.9+ KB

# %% [markdown]
# 단일 ip_month 파일로 합치기

# %%
ip_m_grade = ip_month_grade.copy()
ip_m_info = ip_month_info.copy()
ip_m_sales = ip_month_sales.copy()

# %%
ip_month = pd.merge(ip_m_info, ip_m_sales, how = 'left', on = ['ProdNo', 'date'], sort = False)
ip_month.head(5)
# Out:
#    accuCnt  aggrCnt                        author      category  \
# 0        0     6661  토드 홉킨스  레이 힐버트신윤경 역           자기계발
# 1        0     4906                  정철진           경제경영
# 2        0     4527   오쿠다 히데오(奧田英朗)이영미 역             소설
# 3        0     4015                                자기계발
# 4        0     2691        곰돌이   .강경효 그림             아동
#
#             title     ProdNo    date  rank    sales
# 0            청소부밥   15593842  200703     1  30944.0
# 1  대한민국20대재테크에미쳐라   14623522  200703     2  26982.0
# 2            공중그네    2580891  200703     3  49920.0
# 3              배려    4180548  200703     4  42128.0
# 4        영국에서보물찾기  200101744  200703     5   5728.0

# %%
ip_month = pd.merge(ip_month, ip_m_grade, how = 'left', on = ['ProdNo', 'date'], sort = False)
ip_month.head(5)
# Out:
#    accuCnt  aggrCnt                        author      category  \
# 0        0     6661  토드 홉킨스  레이 힐버트신윤경 역           자기계발
# 1        0     4906                  정철진           경제경영
# 2        0     4527   오쿠다 히데오(奧田英朗)이영미 역             소설
# 3        0     4015                                자기계발
# 4        0     2691        곰돌이   .강경효 그림             아동
#
#             title     ProdNo    date  rank    sales  review
# 0            청소부밥   15593842  200703     1  30944.0     9.5
# 1  대한민국20대재테크에미쳐라   14623522  200703     2  26982.0     9.0
# 2            공중그네    2580891  200703     3  49920.0     9.3
# 3              배려    4180548  200703     4  42128.0     9.5
# 4        영국에서보물찾기  200101744  200703     5   5728.0     9.7

# %% [markdown]
# 결측치 처리

# %%
ip_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26445 entries, 0 to 26444
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   accuCnt   26445 non-null  int64
#  1   aggrCnt   26445 non-null  int64
#  2   author    26445 non-null  object
#  3   category  26445 non-null  object
#  4   title     25052 non-null  object
#  5   ProdNo    26445 non-null  object
#  6   date      26445 non-null  int64
#  7   rank      26445 non-null  int64
#  8   sales     19411 non-null  float64
#  9   review    18054 non-null  float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 2.2+ MB

# %%
ip_month.isnull().sum()
# title이 null: 
# sales가 null: 
# review가 null:
# Out:
# accuCnt        0
# aggrCnt        0
# author         0
# category       0
# title       1393
# ProdNo         0
# date           0
# rank           0
# sales       7034
# review      8391
# dtype: int64

# %%
ip_month.title.unique()
# Out:
# array(['청소부밥', '대한민국20대재테크에미쳐라', '공중그네', ..., '또오해하는말더이해하는말',
#        '불장난(제45회이상문학상작품집2022년)', '서영동이야기'], dtype=object)

# %%
ip_m_sales[ip_m_sales.ProdNo == '88385538758810(409803015094350514158)']
# Out:
# Empty DataFrame
# Columns: [sales, ProdNo, date]
# Index: []

# %% [markdown]
# + 중도 isbn (책 제목 결측치 끌어올수 있는지 확인하는 용도)

# %%
isbn = pd.read_csv(r'C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\joongdo_notyet.csv')
isbn.head(3)
# Out:
# C:\Users\maeve\AppData\Local\Temp\ipykernel_14364\3439157384.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   isbn = pd.read_csv(r'C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\joongdo_notyet.csv')
#    Unnamed: 0  index                            title                author  \
# 0           0      0                       21세기 사회주의   지은이: 콜린 바커 ;옮긴이: 이수현
# 1           1      0                      질풍노도 연재 120                    금강
# 2           2      0  2013년 (중간시험 범위) 중간고사 기출예상문제 1-2                   편집부
#
#      pub_date          pub isbn_add_code        repub           isbn ebook  \
# 0  20130528.0  (노동자연대) 다함께        3300.0  (노동자연대) 다함께  9788996911043     N
# 1  20130701.0          문피아        5810.0          문피아  9791130515137     Y
# 2  20130826.0      (주)천재교육       63370.0      (주)천재교육  9788926970546     N
#
#    price SUBJECT  pub_year  pub_month  pub_day
# 0   3000       3    2013.0        5.0     28.0
# ...

# %%
isbn[(isbn.author == '김호연')&(isbn.isbn == '409803015094350514158')] # 88385538758810(409803015094350514158)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, index, title, author, pub_date, pub, isbn_add_code, repub, isbn, ebook, price, SUBJECT, pub_year, pub_month, pub_day]
# Index: []

# %%
ip_month.tail(150)
# Out:
#        accuCnt  aggrCnt               author      category  \
# 26295     8238     1442         김호연             소설
# 26296     1942      825      열린공감             사회과학
# 26297     3650      641         한성희             인문
# 26298      854      471  기욤 뮈소양영란 역             소설
# 26299     4654      457         박근혜           사회과학
# ...        ...      ...                  ...           ...
# 26440      198       74         정규범           경제경영
# 26441     5693       73         송희창           경제경영
# 26442     3891       73         김소영           시에세이
# 26443      326       73         배진한           경제경영
# 26444       94       73         조남주             소설
#
#                            title                                 ProdNo  \
# 26295                        NaN  88385538758810(409803015094350514158)
# 26296                      윤석열파일                              354469959
# 26297  딸에게보내는심리학편지(10만부기념스페셜에디션)                              326631984
# ...

# %% [markdown]
# 작가명이 '         '인 경우 (5306건) / 결측치는 x (무시?)

# %%
ip_month[ip_month.author == '         ']
# Out:
#        accuCnt  aggrCnt     author        category        title     ProdNo  \
# 3            0     4015               자기계발                   배려    4180548
# 6            0     2199                 아동           우리들의일그러진영웅     109266
# 16           0     1365                 아동                자전거도둑     274029
# 22           0     1181                 아동               까막눈삼디기     540458
# 32           0      907                 여행            지도밖으로행군하라    3499506
# ...        ...      ...        ...             ...          ...        ...
# 26368      194      119                 아동          흔한남매의흔한호기심5  354482796
# 26374    30523      114                 소설                  아몬드  266107628
# 26379    45351      109               시에세이             꽃을보듯너를본다  240658700
# 26415       76       82             가정과 생활              베이킹하다앳홈  354492827
# 26428    20634       77                 소설                소년이온다  216570816
#
#          date  rank    sales  review
# ...

# %%
ip_month.to_csv(r'C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\ip_month.csv')

# %%
ip_month.iloc[6].author
# Out:
# '         '

# %% [markdown]
# + 결측치 관련 단상: 장르, 판매량, 후기만 살아있다면 그냥 둬도 괜찮지 않을까?

# %% [markdown]
# 1~4기 시기별 장르 판매량
# - 2020.1~2020.7
# - 2020.8~2021.2
# - 2021.7~2022.1
# - 2022.2~2022.11현재

# %%
ip_month[(202001 <= ip_month.date)&(ip_month.date <= 202007)].sort_values(by = 'date').groupby('category').sum().sort_values(by='sales', ascending = False).head(15)
# Out:
#                   accuCnt  aggrCnt      date   rank     sales  review
# category
# 소설                1488717    47927  21008433   7829  941271.0   840.2
# 인문                1702998    52967  23836464   8356  785486.0   881.4
# 시에세이               912580    43681  18180372   6352  586617.0   804.2
# 경제경영               475410    68392  30300661  10151  577960.0  1231.6
# 자기계발               543562    50159  18180363   6817  419924.0   793.5
# 아동                 347317    48329  20402425   7509  276770.0   728.7
# 역사                 862569     8769   4242102   1194  268848.0   135.5
# 자연과 과학             350177    12192   5656095   1792  255747.0   188.7
# 국어외국어사전            243388    24756  12322207   4167  226078.0   402.8
# 유아                 246996     3596   2828060   1516  117883.0    96.2
# 가정과 생활             115471     7909   5656105   2613   75377.0   264.6
# 청소년                123179     3873   2626058   1264   75197.0    68.0
# ...

# %%
ip_month[(ip_month.category == '사회과학        ')&(ip_month.date >= '202001')&(ip_month.date <= '202012')]
# Out:
#        accuCnt  aggrCnt                                author      category  \
# 21360     1183     1082               도리스 컨스 굿윈강주헌 역           사회과학
# 21388     2825      601                          김지혜           사회과학
# 21434      423      395                          김누리           사회과학
# 21496     4596     2055                    팀 마샬김미선 역           사회과학
# 21646     6263     1565                    팀 마샬김미선 역           사회과학
# 21736     3481      218                          김지혜           사회과학
# 21806     7307      858                    팀 마샬김미선 역           사회과학
# 21849      547      312             데이비드 월러스 웰즈김재경 역           사회과학
# 21886     3785      227                          김지혜           사회과학
# 21920      297      185                  토마 피케티안준범 역           사회과학
# 21970     7992      534                    팀 마샬김미선 역           사회과학
# 21978      904      485                     김지은  김지은           사회과학
# 22062      789      220             데이비드 월러스 웰즈김재경 역           사회과학
# ...

# %%
ip_month[(ip_month.category == '경제경영        ')&(ip_month.date >= '202001')&(ip_month.date <= '202012')].sort_values(by='sales', ascending = False).head(100)
# Out:
#        accuCnt  aggrCnt        author      category  \
# 21948     4727     2128  김승호           경제경영
# 22099     7065     2137  김승호           경제경영
# 21797     2404     2232  김승호           경제경영
# 22401    11497     1509  김승호           경제경영
# 22706    14701     1515  김승호           경제경영
# ...        ...      ...           ...           ...
# 21513     3088      730  사경인           경제경영
# 22747     6512      493  사경인           경제경영
# 22876      525      498  사경인           경제경영
# 22281     5402      489  사경인           경제경영
# 21987     4429      380  사경인           경제경영
#
#                                title     ProdNo    date  rank    sales  review
# 21948               돈의속성(200쇄리커버에디션)  333280883  202007     4  13519.0     9.5
# 22099               돈의속성(200쇄리커버에디션)  333280883  202008     5  13519.0     9.5
# 21797               돈의속성(200쇄리커버에디션)  333280883  202006     3  13519.0     9.5
# 22401               돈의속성(200쇄리커버에디션)  333280883  202010     7  13519.0     9.5
# ...

# %%
ip_month[(202008 <= ip_month.date)&(ip_month.date <= 202102)].sort_values(by = 'date').groupby('category').sum().sort_values(by='sales', ascending = False).head(15)
# Out:
#                  accuCnt  aggrCnt      date   rank     sales  review
# category
# 경제경영              960738   142272  42227614  12131  818509.0  1713.0
# 소설               1643307    73385  21415799   6749  814087.0   791.4
# 인문               1137223    40711  19799085   7638  513297.0   743.0
# 자기계발              525860    32574  13940526   4748  384041.0   588.4
# 시에세이              475420    49281  18990689   5985  350061.0   871.0
# 자연과 과학            360035     6896   4242669   1580  229210.0   143.1
# 국어외국어사전           339740    24956  12325168   4620  212457.0   394.3
# 아동                163479    30801  15758236   6371  152750.0   529.2
# 가정과 생활            190610    23489   5455003   1696  143906.0   242.1
# 청소년               187215    14079   5656735   1889  135188.0   186.9
# 역사                612189     5821   3232616   1121  119382.0    76.8
# 유아                205157     3389   2020285    754  104551.0    88.0
# ...

# %%
ip_month[(202107 <= ip_month.date)&(ip_month.date <= 202201)].sort_values(by = 'date').groupby('category').sum().sort_values(by='sales', ascending = False).head(15)
# Out:
#                   accuCnt  aggrCnt      date   rank     sales  review
# category
# 자기계발              1104308    18350  17989141   6944  941298.0   648.8
# 경제경영              1080002    61327  49116240  17307  795651.0  1909.8
# 소설                1160895    40141  23648476   7455  629471.0   765.9
# 인문                 623725    19487  17584466   6828  455198.0   693.4
# 시에세이               378000    15598  14957390   5963  311596.0   620.0
# 아동                 101318    18585  17988976   6741  305798.0   537.2
# 국어외국어사전            356514    10035   9500050   3803  270928.0   272.6
# 가정과 생활             186628     8371   7276411   2717  235153.0   335.1
# 자연과 과학             337021     2210   3031917   1431  200021.0    56.2
# ¿⁄±‚∞ëπþ           226348      654    606323    314  124175.0    28.9
# 자격서수험서              37075     7660   6670438   2209  115853.0   302.7
# 청소년                202848     4274   4648703   2054  102218.0   116.3
# ...

# %%
ip_month[(202202 <= ip_month.date)&(ip_month.date <= 202211)].sort_values(by = 'date').groupby('category').sum().sort_values(by='sales', ascending = False).head(15)
# Out:
#                   accuCnt  aggrCnt      date   rank      sales  review
# category
# 자기계발              1441573    20126  31341994  11181  1992264.0  1219.4
# 소설                 721567    35770  31139786  10190  1763396.0   959.8
# 경제경영               640015    25802  39025680  14509  1505155.0  1548.9
# 인문                1006568    16148  24466967   9288  1395036.0   934.3
# 시에세이               326667    12524  19411813   7659   963042.0   864.9
# 아동                  67753    10995  19816223   7658   596697.0   656.5
# 국어외국어사전            229319     4748   7886032   2853   492168.0   342.9
# 자연과 과학             401293     3327   5863982   2330   403110.0   209.0
# 가정과 생활              96840     4093   8694840   4056   361623.0   415.0
# 자격서수험서              50370     5234  10514692   4590   352138.0   445.7
# └┌▒ō░ķ╣▀           255971     1898   1415430    391   212010.0    39.3
# 사회과학                99527     7301   6470569   2370   176211.0   264.9
# ...

# %% [markdown]
# # 연간

# %%
ip_year_grade.shape, ip_year_info.shape, ip_year_sales.shape
# Out:
# ((1400, 5), (1500, 9), (1500, 5))

# %%
ip_year_grade.drop(['Unnamed: 0', 'index'], axis = 1, inplace = True)
ip_year_grade.head(3)
# Out:
#       ProdNo  review  date
# 0    2225586     9.0  2013
# 1    4596705     9.5  2013
# 2  201695879     6.0  2013

# %%
ip_year_info.drop(['index'], axis = 1, inplace = True)
ip_year_info.head(3)
# Out:
#    accuCnt  aggrCnt                  author      category        title  \
# 0   216084    58568                          시에세이          멈추면비로소보이는것들
# 1    90440    55056  프랑수아 를로르오유란 역             소설             꾸뻬씨의행복여행
# 2    46823    24695       조정래(趙廷來)             소설                정글만리1
#
#       ProdNo  date  rank
# 0  209739185  2013     1
# 1    2225586  2013     2
# 2  212675918  2013     3

# %%
ip_year_sales.drop(['Unnamed: 0', 'index'], axis = 1, inplace = True)
ip_year_sales = ip_year_sales.rename(columns={'구매력?': 'sales'})
ip_year_sales.head(3)
# Out:
#    sales   ProdNo  date
# 0  65947   233410  2013
# 1  43835  2225586  2013
# 2  58934  4596705  2013

# %%
ip_y_grade = ip_year_grade.copy()
ip_y_info = ip_year_info.copy()
ip_y_sales = ip_year_sales.copy()

# %%
ip_y_grade.ProdNo = ip_y_grade.ProdNo.astype('str')
ip_y_info.ProdNo = ip_y_info.ProdNo.astype('str')
ip_y_sales.ProdNo = ip_y_sales.ProdNo.astype('str')

ip_year = pd.merge(ip_y_info, ip_y_sales, how = 'left', on = ['ProdNo', 'date'], sort = False)
ip_year.head(5)
# Out:
#    accuCnt  aggrCnt                  author      category  \
# 0   216084    58568                          시에세이
# 1    90440    55056  프랑수아 를로르오유란 역             소설
# 2    46823    24695       조정래(趙廷來)             소설
# 3    44322    22567       조정래(趙廷來)             소설
# 4    27200    22166  무라카미 하루키양억관 역             소설
#
#                   title     ProdNo  date  rank     sales
# 0           멈추면비로소보이는것들  209739185  2013     1  108732.0
# 1              꾸뻬씨의행복여행    2225586  2013     2   43835.0
# 2                 정글만리1  212675918  2013     3   23150.0
# 3                 정글만리2  212675983  2013     4   21873.0
# 4  색채가없는다자키쓰쿠루와그가순례를떠난해  212676044  2013     5   13012.0

# %%
ip_year = pd.merge(ip_year, ip_y_grade, how = 'left', on = ['ProdNo', 'date'], sort = False)
ip_year.head(5)
# Out:
#    accuCnt  aggrCnt                  author      category  \
# 0   216084    58568                          시에세이
# 1    90440    55056  프랑수아 를로르오유란 역             소설
# 2    46823    24695       조정래(趙廷來)             소설
# 3    44322    22567       조정래(趙廷來)             소설
# 4    27200    22166  무라카미 하루키양억관 역             소설
#
#                   title     ProdNo  date  rank     sales  review
# 0           멈추면비로소보이는것들  209739185  2013     1  108732.0     9.7
# 1              꾸뻬씨의행복여행    2225586  2013     2   43835.0     9.0
# 2                 정글만리1  212675918  2013     3   23150.0     9.3
# 3                 정글만리2  212675983  2013     4   21873.0     9.3
# 4  색채가없는다자키쓰쿠루와그가순례를떠난해  212676044  2013     5   13012.0     8.7

# %%
ip_year.head(5)
# Out:
#    accuCnt  aggrCnt                  author      category  \
# 0   216084    58568                          시에세이
# 1    90440    55056  프랑수아 를로르오유란 역             소설
# 2    46823    24695       조정래(趙廷來)             소설
# 3    44322    22567       조정래(趙廷來)             소설
# 4    27200    22166  무라카미 하루키양억관 역             소설
#
#                   title     ProdNo  date  rank     sales  review
# 0           멈추면비로소보이는것들  209739185  2013     1  108732.0     9.7
# 1              꾸뻬씨의행복여행    2225586  2013     2   43835.0     9.0
# 2                 정글만리1  212675918  2013     3   23150.0     9.3
# 3                 정글만리2  212675983  2013     4   21873.0     9.3
# 4  색채가없는다자키쓰쿠루와그가순례를떠난해  212676044  2013     5   13012.0     8.7

# %%
ip_year.isnull().sum()
# Out:
# accuCnt       0
# aggrCnt       0
# author        0
# category      0
# title         8
# ProdNo        0
# date          0
# rank          0
# sales        38
# review      138
# dtype: int64

# %%
ip_year.to_csv(r'C:\Users\maeve\AIB 14\Section6\Codestates Project 2\data\clean\interpark\ip_year.csv')

# %%
ip_year.shape
# Out:
# (1500, 10)
